# %%
from pathlib import Path

from credit_scoring.dc5 import run_pipeline, smoke_check

repo_root = next(path for path in (Path.cwd(), *Path.cwd().parents) if (path / "pyproject.toml").is_file())
smoke_check()  # synthetic assertion chạy trước khi đọc dữ liệu thật
run = run_pipeline(config_path=repo_root / "configs" / "dc5_customer_analysis.yaml")
run.display()
run.metrics
